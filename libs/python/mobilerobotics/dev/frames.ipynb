# %%
from mobilerobotics.basic import Frame
from mobilerobotics.carts import MobileCart
from sympy.physics.vector import Point
import sympy as smp
from sympy.physics.vector import ReferenceFrame, Point
from sympy import Matrix
from scipy.spatial.transform import Rotation

world = Frame('world')
cart = MobileCart(parent_frame=world)
smp.pprint(cart.frame.pose2d)
pass
# Out:
# ⎡  x(t)   ⎤
# ⎢         ⎥
# ⎢  y(t)   ⎥
# ⎢         ⎥
# ⎣\theta(t)⎦

# %%
import pyvista as pv
pl = pv.Plotter()
#pl.add_mesh(pv.Cylinder(), show_edges=True)
# pl.show_bounds()
pl.show_axes_all()
pl.add_actor(pv.AxesAssembly())
# pl.add_actor(pv.Cylinder())
pl.show()
# Out:
# ---------------------------------------------------------------------------
# PyVistaAttributeError                     Traceback (most recent call last)
# Cell In[11], line 7
#       5 pl.show_axes_all()
#       6 pl.add_actor(pv.AxesAssembly())
# ----> 7 pl.add_actor(pv.Cylinder())
#       8 pl.show()
#
# File ~/Documents/Doctorado/Proyectos/2403 - Material Transportation Robot/libs/python/mobilerobotics/.venv/lib/python3.12/site-packages/pyvista/plotting/plotter.py:1512, in BasePlotter.add_actor(self, *args, **kwargs)
#    1507 @wraps(Renderer.add_actor)
#    1508 def add_actor(
#    1509     self, *args, **kwargs
#    1510 ) -> tuple[_vtk.vtkProp, _vtk.vtkProperty | None]:  # numpydoc ignore=PR01,RT01
#    1511     """Wrap ``Renderer.add_actor``."""
# -> 1512     return self.renderer.add_actor(*args, **kwargs)
#
# File ~/Documents/Doctorado/Proyectos/2403 - Material Transportation Robot/libs/python/mobilerobotics/.venv/lib/python3.12/site-packages/pyvista/_deprecate_positional_args.py:245, in _deprecate_positional_args.<locals>._inner_deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#     241             warnings.warn(msg, PyVistaDeprecationWarning, stacklevel=stack_level)
#     243         warn_positional_args()
# --> 245 return f(*args, **kwargs)
#
# File ~/Documents/Doctorado/Proyectos/2403 - Material Transportation Robot/libs/python/mobilerobotics/.venv/lib/python3.12/site-packages/pyvista/plotting/renderer.py:1023, in Renderer.add_actor(self, actor, reset_camera, name, culling, pickable, render, remove_existing_actor)
#    1017 if name is None:
#    1018     name = (
#    1019         actor.name
#    1020         if (hasattr(actor, 'name') and actor.name)
#    1021         else f'{type(actor).__name__}({actor.GetAddressAsString("")})'
#    1022     )
# -> 1023 actor.name = name
#    1024 actor.SetPickable(pickable)
#    1025 # Apply this renderer's scale to the actor (which can be further scaled)
#
# File ~/Documents/Doctorado/Proyectos/2403 - Material Transportation Robot/libs/python/mobilerobotics/.venv/lib/python3.12/site-packages/pyvista/core/utilities/misc.py:329, in _NoNewAttrMixin.__setattr__(self, key, value)
#     323     from pyvista import PyVistaAttributeError  # noqa: PLC0415
#     325     msg = (
#     326         f'Attribute {key!r} does not exist and cannot be added to class '
#     327         f'{self.__class__.__name__!r}\nUse `pv.set_new_attribute` to set new attributes.'
#     328     )
# --> 329     raise PyVistaAttributeError(msg)
#     330 object.__setattr__(self, key, value)
#
# PyVistaAttributeError: Attribute 'name' does not exist and cannot be added to class 'PolyData'
# Use `pv.set_new_attribute` to set new attributes.
