# %%
from mobilerobotics.basic import Frame
from mobilerobotics.carts import MobileCart
from mobilerobotics.visualization.cartviz import *
from sympy.physics.vector import Point
import sympy as smp
from sympy.physics.vector import ReferenceFrame, Point
from sympy import Matrix
from scipy.spatial.transform import Rotation

world = Frame('world')
cart = MobileCart(parent_frame=world)
smp.pprint(cart.frame.pose2d)
viz3d = CartViz3D(cart)
pass
# Out:
# [20250822-132637.524 __init__.py->wrapper():342]DEBUG: matplotlib data path: /home/guillermo/Documents/Doctorado/Proyectos/2403 - Material Transportation Robot/libs/python/mobilerobotics/.venv/lib/python3.12/site-packages/matplotlib/mpl-data
# [20250822-132637.532 __init__.py->wrapper():342]DEBUG: CONFIGDIR=/home/guillermo/.config/matplotlib
# [20250822-132637.548 __init__.py-><module>():1560]DEBUG: interactive is False
# [20250822-132637.549 __init__.py-><module>():1561]DEBUG: platform is linux
# ⎡  x(t)   ⎤
# ⎢         ⎥
# ⎢  y(t)   ⎥
# ⎢         ⎥
# ⎣\theta(t)⎦
# [20250822-132637.620 __init__.py->wrapper():342]DEBUG: CACHEDIR=/home/guillermo/.cache/matplotlib
# [20250822-132637.627 font_manager.py->_load_fontmanager():1635]DEBUG: Using fontManager instance from /home/guillermo/.cache/matplotlib/fontlist-v390.json
# /home/guillermo/Documents/Doctorado/Proyectos/2403 - Material Transportation Robot/libs/python/mobilerobotics/.venv/lib/python3.12/site-packages/pyvista/jupyter/notebook.py:56: UserWarning: Failed to use notebook backend:
#
# No module named 'trame'
#
# Falling back to a static output.
#   warnings.warn(
# <PIL.Image.Image image mode=RGB size=1024x768>
